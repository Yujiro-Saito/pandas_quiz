# %%
import pandas as pd

# %%
war = pd.read_csv("War.csv")

# %%
war.head(100)
# Out:
#                                           Name             Time  \
# 0                                 World War II        1939–1945
# 1                             Mongol conquests        1206–1324
# 2                            Taiping Rebellion        1850–1864
# 3                           Three Kingdoms War          184–280
# 4                     Conquest of the Americas        1492–1691
# 5                     Second Sino-Japanese War        1937–1945
# 6        Qing dynasty conquest of Ming Dynasty        1616–1662
# 7                   Spanish conquest of Mexico        1519–1632
# 8                          An Lushan Rebellion          755–763
# 9                                  World War I        1914–1918
# 10                               Dungan Revolt        1862–1877
# 11                               Conquests of         1370–1405
# 12                    Spanish conquest of Peru        1533–1620
# 13                           Chinese Civil War        1927–1949
# ...

# %%
war.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 3 columns):
# Name          216 non-null object
# Time          213 non-null object
# Casualties    216 non-null object
# dtypes: object(3)
# memory usage: 5.1+ KB

# %%
war.sort_values(by = "Casualties",ascending=False)
# Out:
#                                         Name                  Time  \
# 91                               Bosnian War             1991-1995
# 90                                  Aceh War             1873-1914
# 27                 Soviet war in Afghanistan             1979–1989
# 208                      2013 Guinea clashes                  2013
# 144                         Libyan Civil War                  2011
# 92                     Arab Israeli conflict          1948-present
# 93                               Mahdist War             1881-1889
# 185                            Falklands War                  1982
# 34             War of the Spanish Succession             1701-1714
# 95                                   Rif War             1916-1927
# 94   Third conflict in the Goryeo Khitan War             1018-1019
# 33                        American Civil War             1861-1865
# 35                         English Civil War             1642-1651
# ...
